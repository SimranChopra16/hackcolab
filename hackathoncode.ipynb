# %% [markdown]
# <a href="https://colab.research.google.com/github/SimranChopra16/hackcolab/blob/main/hackathoncode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Replace with your details
# !git config --global user.email "simranchopra2007@gmail.com"
# !git config --global user.name "SimranChopra16"

# %%
# !git clone https://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/SimranChopra16/repository.git

# Change directory into your repo
# %cd repository

# Copy your dataset from Drive into this folder (if you want to upload it)
# !cp /content/drive/MyDrive/path/to/your/dataset.csv .

# %%
# 1. GitHub Repository ko Clone karein
# !git clone https://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@github.com/SimranChopra16/hackcolab.git

# 2. Repository folder ke andar jayein
# %cd hackcolab

# 3. Drive se dataset copy karein
# (Note: Agar file ka naam alag hai, toh niche 'apni_file.csv' mita kar apna sahi path paste kar dena)
# !cp "/content/drive/MyDrive/apni_file.csv" .
# Out:
# Cloning into 'hackcolab'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/hackcolab
# cp: cannot stat '/content/drive/MyDrive/apni_file.csv': No such file or directory

# %%
# !git config --global user.email "simranchopra2007@gmail.com"
# !git config --global user.name "SimranChopra16"

# 2. Saari files ko line mein lagao (Stage files)
# !git add .

# 3. Message likho ki aapne kya badlav kiya hai
# !git commit -m "Added code and dataset from Colab"

# 4. GitHub par bhej do (Push)
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/SimranChopra16/hackcolab.git (fetch)
# origin	https://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@github.com/SimranChopra16/hackcolab.git (push)

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
